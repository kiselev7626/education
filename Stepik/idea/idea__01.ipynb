# %%
# кодировщик
# уровень 1 берем таблицу уникод, через chr меняем символ на номер
# уровень 2 смещаем как у Цезаря на n символов

# кодировщик
#text=str(input())
import win32clipboard
text='У лукоморья дуб зелёный'
for i in range(len(text)):
    print(ord(text[i]), end='.')
win32clipboard.SetClipboardText
# Out:
# 1059.32.1083.1091.1082.1086.1084.1086.1088.1100.1103.32.1076.1091.1073.32.1079.1077.1083.1105.1085.1099.1081.
# <function win32clipboard.SetClipboardText>

# %%
# Кодировщик
text=str(input())
#text='У лукоморья дуб зелёный'
#out1=[]
#out2=a
for i in range(len(text)):
    print(ord(text[i]), end='.')
#    out1.append(ord(text[i]))
#    out2
#print(out1)
#print(out2)
# Out:
# 1051.1102.1073.1086.1081.32.1085.1072.1073.1086.1088.32.1076.1072.1085.1085.1099.1093.32.1074.32.1086.1087.1077.1088.1072.1090.1080.1074.1085.1086.1081.32.1087.1072.1084.1103.1090.1080.32.1082.1086.1084.1087.1100.1102.1090.1077.1088.1072.32.1076.1086.1083.1078.1077.1085.32.1093.1088.1072.1085.1080.1090.1100.1089.1103.32.1074.32.1074.1080.1076.1077.32.1076.1074.1086.1080.1095.1085.1086.1075.1086.32.1095.1080.1089.1083.1072.46.32.1069.1090.1086.32.1086.1090.1085.1086.1089.1080.1090.1089.1103.32.1080.32.1082.32.1089.1090.1088.1086.1082.1072.1084.44.32.1082.1086.1090.1086.1088.1099.1077.32.1089.1086.1089.1090.1086.1103.1090.32.1080.1079.32.1089.1080.1084.1074.1086.1083.1086.1074.32.40.1073.1091.1082.1074.1099.44.32.1079.1085.1072.1082.1080.32.1087.1088.1077.1087.1080.1085.1072.1085.1080.1103.32.1080.32.1090.46.1076.46.41.46.32.1050.1086.1075.1076.1072.32.1089.1080.1084.1074.1086.1083.32.1089.1086.1093.1088.1072.1085.1103.1077.1090.1089.1103.32.1074.32.1087.1072.1084.1103.1090.1080.44.32.
# ...

# %%
# Деодировщик
code=str(input())
#code='1059.32.1083.1091.1082.1086.1084.1086.1088.1100.1103.32.1076.1091.1073.32.1079.1077.1083.1105.1085.1099.1081.'
a=code.split('.')
for i in range(len(a)):
    b=int(a[i])
    print(chr(b), end='')
# Out:
# У лукоморья дуб зелёный

# %%
import pyperclip

# Копирование текста в буфер обмена.
pyperclip.copy("Текст для копирования")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 import pyperclip
#       3 # Копирование текста в буфер обмена.
#       4 pyperclip.copy("Текст для копирования")
#
# ModuleNotFoundError: No module named 'pyperclip'

# %%
import pyperclip

# Получить доступ к содержимому (вставить).
pyperclip.paste()

# %%
>>> import pyperclip as clipboard
# Копирование текста в буфер обмена.
>>> clipboard.copy("Текст для копирования")
# Получить доступ к содержимому (вставить).
>>> clipboard.paste()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 import pyperclip as clipboard
#       2 # Копирование текста в буфер обмена.
#       3 clipboard.copy("Текст для копирования")
#
# ModuleNotFoundError: No module named 'pyperclip'
