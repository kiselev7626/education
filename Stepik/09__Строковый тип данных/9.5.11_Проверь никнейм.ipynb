# %% [markdown]
# Во время собеседования вам предложили решить задачу на валидацию имени пользователя. Пользователь пытается создать никнейм для своего аккаунта в соцсети Y. Правила для корректного никнейма в соцсети Y следующие:
#
# никнейм должен начинаться с символа @
# никнейм должен содержать от
# 5
# 5 до
# 15
# 15 (включительно) символов (включая первый символ @)
# никнейм должен содержать только строчные буквы и цифры (помимо первого символа @)
# Напишите программу, которая выводит «Correct» (без кавычек), если никнейм соответствует всем вышеприведенным правилам, или «Incorrect» (без кавычек) в противном случае.
#
# Формат входных данных
# На вход программе подаётся одна строка – никнейм.
#
# Формат выходных данных
# Программа должна вывести текст в соответствии с условием задачи.
#
# Примечание. Обратите внимание, что никнейму необязательно содержать строчные буквы и цифры одновременно, никнейм может содержать только строчные буквы или только цифры (помимо первого символа @). Например, следующие никнеймы считаются корректными:
#
# @duncan
# @1111
#
# Номер теста	Входные данные	Выходные данные
# 1
# @paul_atreides
# Incorrect
# 2
# @chani7
# Correct
# 3
# @stilgar
# Correct
# 4
# @lisan_al_gaib
# Incorrect
# 5
# leto
# Incorrect
# 6
# @BaronVladimirHarkonnen
# Incorrect
# 7
# @baronvladimirharkonnen
# Incorrect
# 8
# @vladimir
# Correct
# 9
# 0feydrautha0
# Incorrect
# 10
# @11112222333344
# Correct
# 11
# @111122223333444
# Incorrect
# 12
# @Rabban666
# Incorrect
# 13
# @rabban666
# Correct
# 14
# @1234
# Correct
# 15
# @987
# Incorrect
# 16
# @abc
# Incorrect
# 17
# @ABCD
# Incorrect
# 18
# @@ladyjessica
# Incorrect

# %%
a=input()
b=list(a)
#print(b)
c = b[1:len(b)]
#print(c)
#print()
count=0
if len(b)>=5 or len(b)<=15:
    count+=1
    print('count lenght =', count)
if b[0]=='@':
    count+=1
print('count @', count)
print('_1_')
for i in range(1, len(b)):
    if b[i]!='a' and b[i]!='b' and b[i]!='c' and b[i]!='d' and b[i]!='e' and b[i]!='f' and b[i]!='g' and b[i]!='h' and b[i]!='i' and b[i]!='j' and b[i]!='k' and b[i]!='l' and b[i]!='m' and b[i]!='n' and b[i]!='o' and b[i]!='p' and b[i]!='q' and b[i]!='r' and b[i]!='s' and b[i]!='t' and b[i]!='u' and b[i]!='v' and b[i]!='w' and b[i]!='x' and b[i]!='y' and b[i]!='z' and b[i]!=0 and b[i]!=1 and b[i]!=2 and b[i]!=3 and b[i]!=4 and b[i]!=5 and b[i]!=6 and b[i]!=7 and b[i]!=8 and b[i]!=9:
        count-=1
        print(i, b[i], count)
print('_2_')
for j in range(1, len(b)):
    if b[j]=='a' or b[j]=='b' or b[j]=='c' or b[j]=='d' or b[j]=='e' or b[j]=='f' or b[j]=='g' or b[j]=='h' or b[j]=='i' or b[j]=='j' or b[j]=='k' or b[j]=='l' or b[j]=='m' or b[j]=='n' or b[j]=='o' or b[j]=='p' or b[j]=='q' or b[j]=='r' or b[j]=='s' or b[j]=='t' or b[j]=='u' or b[j]=='v' or b[j]=='w' or b[j]=='x' or b[j]=='y' or b[j]=='z' or b[j]==0 or b[j]==1 or b[j]==2 or b[j]==3 or b[j]==4 or b[j]==5 or b[j]==6 or b[j]==7 or b[j]==8 or b[j]==9:
        count+=1
        print(j, b[j], count)
print('_3_')
#print(len(b)-1)
#if a.isdigit()==True:
print('digit', a.isdigit())
#if a.isalpha()==True:
print('alpha', a.isalpha())
if (len(b)-1)*2==count:
    print('Correct')
else:
    print('Incorrect')

# Добавить что есть и буквы и цифры
# Добавить что нет других символов
# join без первого символа

# %%
a=input()
b=list(a)
#print(b)
c = b[1:len(b)]
#print(c)
#print()
count=0

# rule 1
if len(b)>=5 and len(b)<=15:
    rule_1=1
else:
    rule_1=0
print('rule_1 =', rule_1)

# rule 2
if b[0]=='@':
    rule_2=1
else:
    rule_2=0
print('rule_2 =', rule_1)

# rule_3
rule_3 = 0
for i in range(1, len(b)):
    if b[i]!='a' and b[i]!='b' and b[i]!='c' and b[i]!='d' and b[i]!='e' and b[i]!='f' and b[i]!='g' and b[i]!='h' and b[i]!='i' and b[i]!='j' and b[i]!='k' and b[i]!='l' and b[i]!='m' and b[i]!='n' and b[i]!='o' and b[i]!='p' and b[i]!='q' and b[i]!='r' and b[i]!='s' and b[i]!='t' and b[i]!='u' and b[i]!='v' and b[i]!='w' and b[i]!='x' and b[i]!='y' and b[i]!='z' and b[i]!='0' and b[i]!='1' and b[i]!='2' and b[i]!='3' and b[i]!='4' and b[i]!='5' and b[i]!='6' and b[i]!='7' and b[i]!='8' and b[i]!='9':
        rule_3-=1
print(i, b[i], 'rule_3 =', rule_3)

# rule 4
rule_4 = 0
for j in range(1, len(b)):
    if b[j]=='a' or b[j]=='b' or b[j]=='c' or b[j]=='d' or b[j]=='e' or b[j]=='f' or b[j]=='g' or b[j]=='h' or b[j]=='i' or b[j]=='j' or b[j]=='k' or b[j]=='l' or b[j]=='m' or b[j]=='n' or b[j]=='o' or b[j]=='p' or b[j]=='q' or b[j]=='r' or b[j]=='s' or b[j]=='t' or b[j]=='u' or b[j]=='v' or b[j]=='w' or b[j]=='x' or b[j]=='y' or b[j]=='z' or b[j]=='0' or b[j]=='1' or b[j]=='2' or b[j]=='3' or b[j]=='4' or b[j]=='5' or b[j]=='6' or b[j]=='7' or b[j]=='8' or b[j]=='9':
        rule_4 += 1
        print(j, b[j], 'rule_4', rule_4)

if rule_1 == 1 and rule_2 ==1 and rule_3 ==0 and rule_4 == len(b)-1:
    print('Correct')
else:
    print('Incorrect')

# Добавить что есть и буквы и цифры
# Добавить что нет других символов
# join без первого символа

# %%
a=input()
b=list(a)
c = b[1:len(b)]

# rule 1
if len(b)>=5 and len(b)<=15:
    rule_1=1
else:
    rule_1=0

# rule 2
if b[0]=='@':
    rule_2=1
else:
    rule_2=0

# rule_3
rule_3 = 0
for i in range(1, len(b)):
    if b[i]!='a' and b[i]!='b' and b[i]!='c' and b[i]!='d' and b[i]!='e' and b[i]!='f' and b[i]!='g' and b[i]!='h' and b[i]!='i' and b[i]!='j' and b[i]!='k' and b[i]!='l' and b[i]!='m' and b[i]!='n' and b[i]!='o' and b[i]!='p' and b[i]!='q' and b[i]!='r' and b[i]!='s' and b[i]!='t' and b[i]!='u' and b[i]!='v' and b[i]!='w' and b[i]!='x' and b[i]!='y' and b[i]!='z' and b[i]!='0' and b[i]!='1' and b[i]!='2' and b[i]!='3' and b[i]!='4' and b[i]!='5' and b[i]!='6' and b[i]!='7' and b[i]!='8' and b[i]!='9':
        rule_3-=1

# rule 4
rule_4 = 0
for j in range(1, len(b)):
    if b[j]=='a' or b[j]=='b' or b[j]=='c' or b[j]=='d' or b[j]=='e' or b[j]=='f' or b[j]=='g' or b[j]=='h' or b[j]=='i' or b[j]=='j' or b[j]=='k' or b[j]=='l' or b[j]=='m' or b[j]=='n' or b[j]=='o' or b[j]=='p' or b[j]=='q' or b[j]=='r' or b[j]=='s' or b[j]=='t' or b[j]=='u' or b[j]=='v' or b[j]=='w' or b[j]=='x' or b[j]=='y' or b[j]=='z' or b[j]=='0' or b[j]=='1' or b[j]=='2' or b[j]=='3' or b[j]=='4' or b[j]=='5' or b[j]=='6' or b[j]=='7' or b[j]=='8' or b[j]=='9':
        rule_4 += 1

if rule_1 == 1 and rule_2 ==1 and rule_3 ==0 and rule_4 == len(b)-1:
    print('Correct')
else:
    print('Incorrect')
